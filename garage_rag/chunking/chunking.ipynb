# %%
from chunking_functions import *

# %%
content=extract_content("docs/car_final.txt")
content_parts=content.split("[SEP]")

# %%
chunks=[create_chunk(part.strip()) for part in content_parts]

# %%
chunks=[create_chunk(part.strip()) for part in content_parts]
for c in chunks:
        insert_chunk(c)
# Out:
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.
# Successfully inserted chunk.

# %%
create_hnsw_index("chunk")

# %%
from search_functions import *

# %%
retrieve_content("when to change the air  filter")
# Out:
# {'content': '[# Cabin Air Filter]\n# Cabin Air Filter\nWhen to Change: Every 15,000–25,000 km, Or once a year\nWhy: Filters dust, pollen, and pollution from the air entering the cabin.\nSymptoms: Weak AC airflow, Bad smell inside car, Foggy windows, More dust inside cabin\nRisks if Ignored: Poor air quality, AC system strain\nParts to Replace: Cabin air filter\n\n[# Engine Air Filter]\n# Engine Air Filter\nWhen to Change: Every 15,000–30,000 km\nWhy: The filter blocks dust and dirt from entering the engine.\nSymptoms: Reduced power, Higher fuel consumption, Dirty black filter\nRisks if Ignored: Poor combustion, Dirt entering engine\nParts to Replace: Air filter\n\n[# Dirty Air Filter]\n# Dirty Air Filter\nSound: Deep intake noise, Struggling engine sound\nWhat Broke: Air filter clogged with dirt.\nWhat Drivers Notice: Weak engine, High fuel consumption\nHow to Recognize While Driving: Weak acceleration, Higher fuel consumption\nMain Causes: Dust, Old filter, Lack of maintenance\nIs It Dangerous?: ⚠️ Low Risk\nEasy or Garage?: ✅ Very simple\nTypical Fix: Replace air filter'}
