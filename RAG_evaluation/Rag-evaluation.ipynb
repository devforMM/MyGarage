# %%
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage
from agent import Agent

# %%
gemini_questions = [
    # Basé sur car_final.txt
    "What are the main causes and typical fixes for worn brake pads?",
    "How can a driver recognize a bad steering rack while driving, and is a garage required for the repair?",
    "What does it mean if you hear a roaring or airplane-like noise that gets louder with speed?",
    "What should you do if you hear a rhythmic clunking or wobbling noise and notice wheel wobble that increases with speed?",
    "What are the main causes of engine overheating, and what are the typical fixes?",
    "How can you recognize a bad clutch while driving?",
]

gemini_answers = [
    # car_final.txt
    """The main causes are normal wear, cheap pads, and aggressive braking[cite: 159, 160]. The typical fix is to replace the brake pads and check the brake rotors[cite: 160].""",
    
    """A driver can recognize it by a loose steering feeling, a clunk noise while turning, and an unstable steering feel[cite: 165]. Yes, a garage is required to repair or replace the steering rack[cite: 165].""",

    """This sound indicates a bad wheel bearing[cite: 168, 169]. It means the wheel bearing is worn out due to wear, water damage, impacts, or water intrusion[cite: 169].""",

    """This indicates loose lug nuts, which is extremely dangerous[cite: 174, 175]. You should tighten the lug nuts immediately[cite: 175].""",

    """The main causes are low coolant, a coolant leak, or old cooling parts[cite: 22]. Typical fixes include repairing the leak, replacing the thermostat or water pump, and refilling the coolant[cite: 22].""",

    """You can recognize a bad clutch by hard shifting and noticing that the RPM rises without acceleration[cite: 177].""",
]

# %%
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage

for question, expected in zip(gemini_questions, gemini_answers):
    result = Agent.invoke(
        {
            "messages": [
                HumanMessage(content=question)
            ]
        }
    )

    prediction = result["messages"][-1].content

    print("=" * 100)
    print("Question:")
    print(question)
    print()
    print("Expected:")
    print(expected)
    print()
    print("Prediction:")
    print(prediction)
    print()
# Out:
# ...
# Question:
# What are the main causes and typical fixes for worn brake pads?
#
# Expected:
# The main causes are normal wear, cheap pads, and aggressive braking[cite: 159, 160]. The typical fix is to replace the brake pads and check the brake rotors[cite: 160].
#
# Prediction:
# The main causes of worn brake pads include normal wear, using cheap pads, and aggressive braking. The typical fix involves replacing the brake pads and checking the brake rotors.
#
# ...
# Question:
# How can a driver recognize a bad steering rack while driving, and is a garage required for the repair?
#
# Expected:
# A driver can recognize it by a loose steering feeling, a clunk noise while turning, and an unstable steering feel[cite: 165]. Yes, a garage is required to repair or replace the steering rack[cite: 165].
#
# Prediction:
# ...
